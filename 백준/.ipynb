# %%
N = int(input())

bag = 0
while True:
    if (N%5)==0:
        bag += N/5
        print(format(bag,".0f"))
        break
    N -=3
    bag +=1
    
    if N<0:
        print(-1)
        break
# Out:
#  8
# 2

# %%
A, B = map(int,input().split())
print(A+B)
# Out:
#  9223372036854775807 9223372036854775808
# 18446744073709551615
